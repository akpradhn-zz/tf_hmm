# %%
# imports
from tf_hmm import HiddenMarkovModel
from toy_dataset import toy_dataset
import tensorflow as tf
import time
# %matplotlib inline

# %%
dataset = toy_dataset(1000,32)

# %%
hmm = HiddenMarkovModel(2,2,reports=True)

# %%
hmm.expectation_maximization(dataset,max_steps=1000)
# Out:
# the computation graph has been recreated in 2.1 sec
# the training process has been converged in 14 steps in 2.1 sec

# %%
hmm.plot()

# %%
hmm.mu
# Out:
# array([[-1.29338341,  1.08509563],
#        [ 1.81278743, -2.18354956]])

# %%
hmm.cov
# Out:
# array([[[ 2.30596494,  0.30961932],
#         [ 0.30961932,  1.31119498]],
#
#        [[ 1.63188542, -0.15272104],
#         [-0.15272104,  1.07545833]]])

# %%
hmm.p0
# Out:
# array([ 0.86416105,  0.13583895])

# %%
hmm.tp
# Out:
# array([[ 0.8015243 ,  0.1984757 ],
#        [ 0.49162734,  0.50837266]])

# %%
hmm.posterior(dataset).shape
# Out:
# (1000,)
