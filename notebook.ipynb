# %%
# imports
from tf_hmm import HiddenMarkovModel
from toy_dataset import toy_dataset
import tensorflow as tf
import time
# %matplotlib inline

# %%
dataset = toy_dataset(1000,32)

# %%
hmm = HiddenMarkovModel(2,2,reports=True)

# %%
hmm.expectation_maximization(dataset,max_steps=1000)
# Out:
# 1
# the computation graph has been recreated in 2.0 sec
# 2
# 3
# 4
# 5
# the training process has been converged in 18 steps in 2.3 sec

# %%
hmm.plot()

# %%
hmm.mu
# Out:
# array([[-1.29922194,  1.0970926 ],
#        [ 1.82154902, -2.1622865 ]])

# %%
hmm.cov
# Out:
# array([[[ 2.27054639,  0.31992677],
#         [ 0.31992677,  1.29407924]],
#
#        [[ 1.61154905, -0.13845316],
#         [-0.13845316,  1.06311513]]])

# %%
hmm.p0
# Out:
# array([ 0.86688575,  0.13311425])

# %%
hmm.tp
# Out:
# array([[ 0.80601528,  0.19398472],
#        [ 0.48959626,  0.51040374]])
